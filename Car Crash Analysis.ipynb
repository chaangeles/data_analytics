# %%
import pandas as pd

# %%
data=pd.read_csv('Crash.csv')
data.head()
# Out:
#    Crash identifier    Crash severity  Number of vehicles involved  \
# 0         201740657  Non-Injury Crash                          2.0
# 1         201740657  Non-Injury Crash                          2.0
# 2         201740742  Non-Injury Crash                          2.0
# 3         201740747  Non-Injury Crash                          2.0
# 4         201740650  Non-Injury Crash                          3.0
#
#     Simple / complex crash  Crash year Day of the week Month of year  \
# 0  Multiple Party (Simple)        2017       Wednesday           May
# 1  Multiple Party (Simple)        2017       Wednesday           May
# 2  Multiple Party (Simple)        2017          Friday         April
# 3  Multiple Party (Simple)        2017        Thursday          June
# 4  Multiple Party (Simple)        2017          Monday           May
#
#   Is weekend Holiday Road category  ... Natural Light Primary weather  \
# 0         No     NaN      Motorway  ...      Overcast            Fine
# 1         No     NaN      Motorway  ...      Overcast            Fine
# 2         No     NaN   Minor urban  ...      Overcast      Light rain
# 3         No     NaN  Medium urban  ...      Overcast      Light rain
# 4         No     NaN  Medium urban  ...      Overcast            Fine
#
#   Alcohol Suspected Drugs Involved Driver contribution  Licence status   \
# 0           Unknown           Null     No Contribution          Unknown
# 1           Unknown           Null             Primary          Unknown
# 2           Unknown  Not suspected     No Contribution          Unknown
# 3           Unknown  Not suspected     No Contribution          Unknown
# 4           Unknown           Null             Primary          Unknown
#
#    Five year age group  Road usage type  Road user type   Gender
# 0              Unknown        Car/Wagon          Driver  Unknown
# 1              Unknown              Van          Driver  Unknown
# 2              Unknown        Car/Wagon          Driver  Unknown
# 3              Unknown              Van          Driver  Unknown
# 4              Unknown        Car/Wagon          Driver  Unknown
#
# [5 rows x 36 columns]

# %%
data.sort_values('Crash_identifier', ascending=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24824\4147496182.py in <module>
# ----> 1 data.sort_values('Crash_identifier', ascending=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6320
#    6321             by = by[0]
# -> 6322             k = self._get_label_or_level_values(by, axis=axis)
#    6323
#    6324             # need to rewrap column in Series to apply key function
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1838             values = self.axes[axis].get_level_values(key)._values
#    1839         else:
# -> 1840             raise KeyError(key)
#    1841
#    1842         # Check for duplicates
#
# KeyError: 'Crash_identifier'

# %%
data.sort_values('Crash identifier',ascending=True)
# Out:
#         Crash identifier    Crash severity  Number of vehicles involved  \
# 63044          201600001       Fatal Crash                          1.0
# 63060          201600001       Fatal Crash                          1.0
# 63018          201600001       Fatal Crash                          1.0
# 60298          201600002       Fatal Crash                          1.0
# 60299          201600002       Fatal Crash                          1.0
# ...                  ...               ...                          ...
# 378518        2020209429     Serious Crash                          1.0
# 378522        2020210199  Non-Injury Crash                          1.0
# 378528        2020210432  Non-Injury Crash                          1.0
# 378529        2020210447  Non-Injury Crash                          2.0
# 378544        2020210447  Non-Injury Crash                          2.0
#
#          Simple / complex crash  Crash year Day of the week Month of year  \
# 63044              Single Party        2016          Friday       January
# 63060              Single Party        2016          Friday       January
# 63018              Single Party        2016          Friday       January
# 60298              Single Party        2016          Sunday       January
# 60299              Single Party        2016          Sunday       January
# ...                         ...         ...             ...           ...
# 378518             Single Party        2020          Sunday      December
# 378522             Single Party        2020       Wednesday      February
# 378528             Single Party        2020        Thursday       October
# 378529  Multiple Party (Simple)        2020       Wednesday      November
# 378544  Multiple Party (Simple)        2020       Wednesday      November
#
#        Is weekend             Holiday Road category  ... Natural Light  \
# 63044          No  Christmas New Year   Major rural  ...          Dark
# 63060          No  Christmas New Year   Major rural  ...          Dark
# 63018          No  Christmas New Year   Major rural  ...          Dark
# 60298         Yes  Christmas New Year   Major rural  ...    Bright sun
# 60299         Yes  Christmas New Year   Major rural  ...    Bright sun
# ...           ...                 ...           ...  ...           ...
# 378518        Yes                 NaN     Foot path  ...    Bright sun
# 378522         No                 NaN   Major rural  ...    Bright sun
# 378528         No                 NaN           NaN  ...       Unknown
# 378529         No                 NaN           NaN  ...       Unknown
# 378544         No                 NaN           NaN  ...       Unknown
#
#        Primary weather Alcohol Suspected Drugs Involved Driver contribution  \
# 63044             Fine               NaN            NaN                 NaN
# 63060             Fine               NaN            NaN                 NaN
# 63018             Fine  Suspected-Tested           Null             Primary
# 60298             Fine     Not Suspected           Null             Primary
# 60299             Fine               NaN            NaN                 NaN
# ...                ...               ...            ...                 ...
# 378518            Fine               NaN            NaN                 NaN
# 378522            Fine  Suspected-Tested        Unknown             Primary
# 378528            Null           Unknown           Null             Primary
# 378529            Null           Unknown           Null             Primary
# 378544            Null           Unknown           Null             Partial
#
#         Licence status   Five year age group  Road usage type  Road user type  \
# 63044               NaN                15-19              Van       Passenger
# 63060               NaN                20-24              Van       Passenger
# 63018         Forbidden                35-39              Van          Driver
# 60298           Current                60-64              SUV          Driver
# 60299               NaN                55-59              SUV       Passenger
# ...                 ...                  ...              ...             ...
# 378518              NaN              Unknown             Null            Null
# 378522          Unknown                15-19        Car/Wagon          Driver
# 378528          Unknown                40-44              SUV          Driver
# 378529          Unknown                50-54        Car/Wagon          Driver
# 378544          Unknown              Unknown        Car/Wagon          Driver
#
#          Gender
# 63044      Male
# 63060      Male
# 63018      Male
# 60298      Male
# 60299    Female
# ...         ...
# 378518  Unknown
# 378522     Male
# 378528   Female
# 378529   Female
# 378544     Male
#
# [378819 rows x 36 columns]

# %%
data.drop(data.loc[data['Road user type']!='Driver'].index, inplace=True)

# %%
data.drop(data.loc[data['Road user type']!='Driver'].index, inplace=True)

# %%
DC_Index=data.columns.get_loc("Driver Contribution")
print(DC_Index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Driver Contribution'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24824\62572129.py in <module>
# ----> 1 DC_Index=data.columns.get_loc("Driver Contribution")
#       2 print(DC_Index)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Driver Contribution'

# %%
DC_Index=data.columns.get_loc("Driver contribution")
print(DC_Index)
# Out:
# 30

# %%
Total_Index=data.shape[0]
print(Total_Index)
NC_List=[]
count=0
NC=0
for x in range (Total_Index):
    if (data.iloc[x][30])=='Primary' or data.iloc[x][30]=='Partial' or data.iloc[x][30]=='No Contribution'):
        count+=1
    else
        NC+=1
        NC_List.append(x)
print(count)
print(NC)
print(NC_List)
# Out:
#   File "C:\Users\chamo\AppData\Local\Temp\ipykernel_24824\594598770.py", line 7
#     if (data.iloc[x][30])=='Primary' or data.iloc[x][30]=='Partial' or data.iloc[x][30]=='No Contribution'):
#                                                                                                           ^
# SyntaxError: unmatched ')'

# %%
Total_Index=data.shape[0]
print(Total_Index)
NC_List=[]
count=0
NC=0
for x in range (Total_Index):
    if (data.iloc[x][30]=="Primary" or data.iloc[x][30]=='Partial' or data.iloc[x][30]=='No Contribution'):
      
        count+=1
    else:
        NC+=1
        NC_List.append(x)
print(count)
print(NC)
print(NC_List)
# Out:
# 321711
# 321426
# 285
# [11996, 11998, 23437, 189027, 189232, 189260, 189268, 189596, 189798, 189832, 189839, 189841, 189996, 190094, 190206, 190251, 190275, 190614, 190619, 190656, 190717, 190872, 190895, 190897, 191023, 191067, 191135, 191181, 191219, 191295, 192026, 192031, 192579, 195648, 195673, 196152, 196160, 196184, 196221, 196419, 196469, 196541, 196554, 197003, 197120, 197166, 197180, 197301, 197358, 197669, 197693, 197918, 197930, 197960, 198208, 198257, 198350, 198427, 198452, 198550, 198618, 198647, 198716, 198717, 198837, 198901, 199045, 199255, 199270, 199365, 199381, 199399, 199515, 199537, 199613, 199615, 199933, 199944, 200030, 200241, 200243, 200341, 200361, 200472, 200477, 200550, 200581, 200593, 200668, 200823, 200828, 200831, 200920, 200925, 200951, 201170, 201213, 201271, 201291, 201462, 201480, 201502, 201590, 201605, 201650, 201658, 201666, 201670, 201676, 201682, 201691, 201702, 201722, 201746, 201870, 201888, 201911, 201941, 201973, 202124, 202168, 202185, 202214, 202345, 202426, 202525, 202588, 202595, 202643, 202679, 202686, 202855, 203140, 203161, 203256, 203575, 203603, 203651, 203658, 203703, 203728, 203729, 203749, 203767, 203829, 203839, 203840, 203933, 203937, 203948, 204025, 204056, 204084, 204100, 204120, 204136, 204158, 204403, 205136, 205229, 205248, 205719, 206386, 207203, 207221, 207430, 207554, 207680, 207740, 207768, 207786, 207797, 207860, 207899, 207924, 207988, 207994, 208147, 208167, 208324, 208334, 208337, 208480, 208492, 208510, 208525, 208588, 208613, 208673, 208708, 208713, 208851, 208880, 208977, 209142, 209365, 209432, 209472, 209505, 209613, 209728, 210002, 210014, 210032, 210037, 210044, 210067, 210210, 210225, 210253, 210254, 210306, 210325, 210368, 210382, 210389, 210500, 210617, 210698, 210815, 210942, 211090, 211137, 211230, 211361, 211435, 211473, 211549, 211725, 211947, 211951, 212613, 212672, 212783, 212877, 212923, 213078, 213106, 213292, 213364, 213437, 213689, 213695, 213726, 213772, 213783, 213796, 213799, 213837, 213959, 214058, 214097, 214123, 214305, 214315, 214443, 215086, 215095, 215655, 215836, 216536, 226250, 228560, 228576, 228988, 230037, 234925, 237299, 237617, 239794, 247743, 247838, 254914, 257067, 265303, 278831, 290955, 293315, 296442, 300629, 306577, 308178, 313659, 313687, 315965]

, 184146, 184147, 184148, 184149, 184150, 184151, 184152, 184153, 184154, 184155, 184156, 184157, 184158, 184159, 184160, 184161, 184162, 184163, 184164, 184165, 184166, 184167, 184168, 184169, 184170, 184171, 184172, 184173, 184174, 184175, 184176, 184177, 184178, 184179, 184180, 184181, 184182, 184183, 184184, 184185, 184186, 184187, 184188, 184189, 184190, 184191, 184192, 184193, 184194, 184195, 184196, 184197, 184198, 184199, 184200, 184201, 184202, 184203, 184204, 184205, 184206, 184207, 184208, 184209, 184210, 184211, 184212, 184213, 184214, 184215, 184216, 184217, 184218, 184219, 184220, 184221, 184222, 184223, 184224, 184225, 184226, 184227, 184228, 184229, 184230, 184231, 184232, 184233, 184234, 184235, 184236, 184237, 184238, 184239, 184240, 184241, 184242, 184243, 184244, 184245, 184246, 184247, 184248, 184249, 184250, 184251, 184252, 184253, 184254, 184255, 184256, 184257, 184258, 184259, 184260, 184261, 184262, 184263, 184264, 184265, 184266, 184267, 184268, 184269, 184270, 184271, 184272, 184273, 184274, 184275, 184276, 184277, 184278, 184279, 184280, 184281, 184282, 184283, 184284, 184285, 184286, 184287, 184288, 184289, 184290, 184291, 184292, 184293, 184294, 184295, 184296, 184297, 184298, 184299, 184300, 184301, 184302, 184303, 184304, 184305, 184306, 184307, 184308, 184309, 184310, 184311, 184312, 184313, 184314, 184315, 184316]

# %%
data.sort_values("Driver contribution", inplace = True)

# %%
data.drop_duplicates(subset="Crash identifier", keep = 'last', inplace = True)
data.shape
# Out:
# (184317, 36)

# %%
data.to_csv('Crash_Clean.csv', index=False)

# %%
data = pd.read_csv('Crash_Clean.csv')
data.head()
# Out:
#    Crash identifier    Crash severity  Number of vehicles involved  \
# 0         201835437  Non-Injury Crash                          1.0
# 1         201816534       Minor Crash                          1.0
# 2         201810622       Minor Crash                          1.0
# 3         201640094  Non-Injury Crash                          1.0
# 4         201719039       Minor Crash                          1.0
#
#      Simple / complex crash  Crash year Day of the week Month of year  \
# 0              Single Party        2018          Monday         March
# 1  Multiple Party (Complex)        2018          Friday        August
# 2  Multiple Party (Complex)        2018        Thursday       January
# 3              Single Party        2016          Monday           May
# 4  Multiple Party (Complex)        2017        Thursday      November
#
#   Is weekend Holiday   Road category  ... Natural Light Primary weather  \
# 0         No     NaN        Motorway  ...    Bright sun            Fine
# 1         No     NaN  Arterial urban  ...    Bright sun            Fine
# 2         No     NaN    Medium urban  ...    Bright sun            Fine
# 3         No     NaN     Minor rural  ...      Overcast      Heavy rain
# 4         No     NaN  Arterial urban  ...    Bright sun            Fine
#
#   Alcohol Suspected Drugs Involved Driver contribution  Licence status   \
# 0           Unknown  Not suspected     No Contribution          Unknown
# 1  Suspected-Tested  Not suspected     No Contribution          Current
# 2  Suspected-Tested        Unknown     No Contribution          Current
# 3           Unknown           Null     No Contribution          Unknown
# 4           Unknown  Not suspected     No Contribution          Current
#
#    Five year age group  Road usage type  Road user type   Gender
# 0              Unknown            Truck          Driver  Unknown
# 1                70-74        Car/Wagon          Driver   Female
# 2                75-79        Car/Wagon          Driver     Male
# 3              Unknown              SUV          Driver  Unknown
# 4                30-34        Car/Wagon          Driver   Female
#
# [5 rows x 36 columns]

# %%
data.shape
# Out:
# (184317, 36)

# %%
days= ['Sunday','Saturday','Friday','Thursday','Wednesday','Tuesday','Monday']
accident_table = data.groupby(['Crash year', 'Day of the week']).size()
accident_table = accident_table.rename_axis(['Year','Weekday'])\ .unstack('Weekday')\ .reindex(columns=days)
accident_table
# Out:
#   File "C:\Users\chamo\AppData\Local\Temp\ipykernel_24824\3826356391.py", line 3
#     accident_table = accident_table.rename_axis(['Year','Weekday'])\ .unstack('Weekday')\ .reindex(columns=days)
#                                                                     ^
# SyntaxError: unexpected character after line continuation character

# %%
days= ['Sunday','Saturday','Friday','Thursday','Wednesday','Tuesday','Monday']
accident_table = data.groupby(['Crash year', 'Day of the week']).size()
accident_table = accident_table.rename_axis(['Year','Weekday'])\
                            .unstack('Weekday')\
                            .reindex(columns=days)
accident_table
# Out:
# Weekday  Sunday  Saturday  Friday  Thursday  Wednesday  Tuesday  Monday
# Year
# 2016       4447      5548    6373      5787       5406     5106    4545
# 2017       4951      5853    6351      6111       5680     5377    4972
# 2018       4540      5732    6338      5906       5622     5223    5093
# 2019       4543      5419    6053      5481       5332     5239    4826
# 2020       4083      4906    5053      4790       4749     4616    4266

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,10))
sns.heatmap(accident_table, cmap='BuPu',annot=True)
plt.title('\nAccidents by Years and Weekdays\n', fontsize=14, fontweight='bold')
plt.xlabel('Weekday')
plt.ylabel('Year')
# Out:
# Text(95.72222222222221, 0.5, 'Year')

# %%
monthly = data[['Month of year', 'Crash identifier']].groupby(['Month of year']).count()

monthly['Crash identifier'].plot.bar(figsize=(14,7), alpha=0.6, color ='green', label='Total accidents')

plt.rc('xtick',labelsize=22)
plt.title('Accidents per month from 2016 to 2020')
plt.xticks(range(13))
plt.xlim(-1,12)

plt.xlabel('Month')
plt.ylabel('Accidents')
plt.legend()

# %%
monthly = data[['Day of the week', 'Crash identifier']].groupby(['Day of the week']).count()



monthly['Crash identifier'].plot.bar(figsize=(14,7), alpha=0.5, color='b', label='Total accidents')


plt.title('Accidents per month from 2016 to 2020')

plt.rcParams.update({'font.size':22})
plt.xticks(range(7))
plt.xlim(-1,7)

plt.xlabel('Day')
plt.ylabel('Accidents')
plt.legend()

# %%
week=data.groupby("Day of the week")["Crash identifier"].count()
label=week.keys()
plt.pie(x=week, radius=1.6, autopct="%.1f%%", labels=label, pctdistance=0.7)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e0d1c807f0>,
#   <matplotlib.patches.Wedge at 0x1e0d1c80f10>,
#   <matplotlib.patches.Wedge at 0x1e0d1c90670>,
#   <matplotlib.patches.Wedge at 0x1e0d1c90d90>,
#   <matplotlib.patches.Wedge at 0x1e0d1c9c4f0>,
#   <matplotlib.patches.Wedge at 0x1e0d1c9cc10>,
#   <matplotlib.patches.Wedge at 0x1e0d1ceb370>],
#  [Text(1.5324093053677836, 0.8656337105394104, 'Friday'),
#   Text(0.24282451687970022, 1.743168452560492, 'Monday'),
#   Text(-1.1783874185181842, 1.3072884501432922, 'Saturday'),
#   Text(-1.7597915446894175, -0.027087252345614803, 'Sunday'),
#   Text(-1.1234087172812923, -1.354825765158163, 'Thursday'),
#   Text(0.3873655723587167, -1.7168424253120043, 'Tuesday'),
#   Text(1.579695684031888, -0.7759906867037941, 'Wednesday')],
#  [Text(0.9751695579613165, 0.5508578157978065, '16.4%'),
#   Text(0.1545246925598092, 1.1092890152657675, '12.9%'),
#   Text(-0.7498829026933896, 0.8319108319093675, '14.9%'),
#   Text(-1.119867346620538, -0.01723734240175487, '12.2%'),
#   Text(-0.7148964564517314, -0.8621618505551945, '15.2%'),
#   Text(0.24650536422827424, -1.0925360888349116, '13.9%'),
#   Text(1.005260889838474, -0.49381225517514155, '14.5%')])

# %%
week=data.groupby(["Crash year","Crash severity"])["Crash identifier"].count()
week
week.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Crash year,Crash severity'>

# %%
dff = pd.DataFrame(columns=('Crash Severity', 'Longitude','Latitude'))
cs=0
for i in range(data.shape[0]):
    if (data.iloc[i][1]=='Fatal Crash'):
        dff.loc[cs] = [data.iloc[i][1], data.iloc[i][17],data.iloc[i][18]]
        cs+=1
dff.plot(kind="scatter", x="Longitude", y="Latitude", color='red')
plt.ylabel("Latitude", fontsize=18)
plt.xlabel("Longitude", fontsize=18)
plt.show()

# %%
dff = pd.DataFrame(columns=('Crash Severity', 'Longitude','Latitude'))
cs=0
for i in range(data.shape[0]):
    if (data.iloc[i][1]=='Fatal Crash'):
        dff.loc[cs] = [data.iloc[i][1], data.iloc[i][17],data.iloc[i][18]]
        cs+=1
dff.plot(kind="scatter", x="Longitude", y="Latitude", color='red')
plt.ylabel("Latitude", fontsize=18)
plt.xlabel("Longitude", fontsize=18)
plt.show()

# %%
count=0
NC_List=[]
for i in range (data.shape[0]):
    if (data.iloc[i][17]<0):
        NC_List.append(i)
        count+=1
print(count)
print(NC_List)
# Out:
# 31
# [1667, 1670, 2086, 2782, 3135, 3224, 11103, 21969, 36603, 41141, 49391, 58925, 73652, 86568, 111844, 117043, 117978, 121035, 121480, 121938, 124888, 130158, 134597, 143387, 145865, 150354, 153387, 156704, 162576, 176382, 176707]

# %%
data.drop(data.index[[1667, 1670, 2086, 2782, 3135, 3224, 11103, 21969, 36603, 41141, 49391, 58925, 73652, 86568, 111844, 117043, 117978, 121035, 121480, 121938, 124888, 130158, 134597, 143387, 145865, 150354, 153387, 156704, 162576, 176382, 176707]])
# Out:
#         Crash identifier    Crash severity  Number of vehicles involved  \
# 0              201835437  Non-Injury Crash                          1.0
# 1              201816534       Minor Crash                          1.0
# 2              201810622       Minor Crash                          1.0
# 3              201640094  Non-Injury Crash                          1.0
# 4              201719039       Minor Crash                          1.0
# ...                  ...               ...                          ...
# 184312        2020170683       Minor Crash                          3.0
# 184313        2020162962  Non-Injury Crash                          1.0
# 184314        2020164239  Non-Injury Crash                          3.0
# 184315        2020168279  Non-Injury Crash                          2.0
# 184316        2020171074  Non-Injury Crash                          3.0
#
#           Simple / complex crash  Crash year Day of the week Month of year  \
# 0                   Single Party        2018          Monday         March
# 1       Multiple Party (Complex)        2018          Friday        August
# 2       Multiple Party (Complex)        2018        Thursday       January
# 3                   Single Party        2016          Monday           May
# 4       Multiple Party (Complex)        2017        Thursday      November
# ...                          ...         ...             ...           ...
# 184312   Multiple Party (Simple)        2020          Friday       October
# 184313              Single Party        2020       Wednesday     September
# 184314   Multiple Party (Simple)        2020         Tuesday     September
# 184315   Multiple Party (Simple)        2020          Sunday      November
# 184316   Multiple Party (Simple)        2020        Thursday      November
#
#        Is weekend Holiday   Road category  ... Natural Light Primary weather  \
# 0              No     NaN        Motorway  ...    Bright sun            Fine
# 1              No     NaN  Arterial urban  ...    Bright sun            Fine
# 2              No     NaN    Medium urban  ...    Bright sun            Fine
# 3              No     NaN     Minor rural  ...      Overcast      Heavy rain
# 4              No     NaN  Arterial urban  ...    Bright sun            Fine
# ...           ...     ...             ...  ...           ...             ...
# 184312         No     NaN    Medium urban  ...          Dark            Fine
# 184313         No     NaN     Major rural  ...      Overcast      Light rain
# 184314         No     NaN     Major urban  ...    Bright sun            Fine
# 184315        Yes     NaN    Medium urban  ...    Bright sun            Fine
# 184316         No     NaN     Major rural  ...    Bright sun            Fine
#
#        Alcohol Suspected Drugs Involved Driver contribution  Licence status   \
# 0                Unknown  Not suspected     No Contribution          Unknown
# 1       Suspected-Tested  Not suspected     No Contribution          Current
# 2       Suspected-Tested        Unknown     No Contribution          Current
# 3                Unknown           Null     No Contribution          Unknown
# 4                Unknown  Not suspected     No Contribution          Current
# ...                  ...            ...                 ...              ...
# 184312               NaN            NaN                 NaN              NaN
# 184313               NaN            NaN                 NaN              NaN
# 184314               NaN            NaN                 NaN              NaN
# 184315               NaN            NaN                 NaN              NaN
# 184316               NaN            NaN                 NaN              NaN
#
#         Five year age group   Road usage type  Road user type   Gender
# 0                   Unknown             Truck          Driver  Unknown
# 1                     70-74         Car/Wagon          Driver   Female
# 2                     75-79         Car/Wagon          Driver     Male
# 3                   Unknown               SUV          Driver  Unknown
# 4                     30-34         Car/Wagon          Driver   Female
# ...                     ...               ...             ...      ...
# 184312                25-29  No Driver Record          Driver     Male
# 184313                25-29  No Driver Record          Driver     Male
# 184314                60-64  No Driver Record          Driver     Male
# 184315                25-29  No Driver Record          Driver     Male
# 184316                40-44  No Driver Record          Driver     Male
#
# [184286 rows x 36 columns]

# %%
dff = pd.DataFrame(columns=('Crash Severity', 'Longitude','Latitude'))
cs=0
for i in range(data.shape[0]):
    if (data.iloc[i][1]=='Fatal Crash'):
        dff.loc[cs] = [data.iloc[i][1], data.iloc[i][17],data.iloc[i][18]]
        cs+=1
dff.plot(kind="scatter", x="Longitude", y="Latitude", marker='.', alpha=0.2, s=0.5, c='red')
plt.ylabel("Latitude", fontsize=18)
plt.xlabel("Longitude", fontsize=18)
plt.show()
