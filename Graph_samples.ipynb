# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
rng=np.random.RandomState(0)

# %%
x=np.linspace(0,10,100)
plt.plot(x, np.sin(x))
plt.plot(x,np.cos(x))
plt.show()

# %%
fig=plt.figure()
plt.plot(x,np.sin(x),'-')
plt.plot(x,np.cos(x),'--');

# %%
plt.figure()
plt.subplot(2,1,1)
plt.plot(x,np.sin(x))

plt.subplot(2,1,2)
plt.plot(x,np.cos(x));

# %%
x=np.linspace(0,10,250)
y=np.cumsum(rng.randn(250,6),0)

# %%
plt.plot(x,y)
plt.legend('ABCDEF',ncol=2,loc='best')

# %%
import seaborn as sns
tips=sns.load_dataset('tips')

# %%
sns.set()
plt.plot(x,y)
plt.legend('ABCDEF',ncol=2, loc='upper left')

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.petal_length.plot()
# Out:
# <AxesSubplot:>

# %%
iris.sepal_length.plot()
# Out:
# <AxesSubplot:>

# %%
iris.sepal_width.plot()
# Out:
# <AxesSubplot:>

# %%
iris.plot()
plt.legend(loc='lower left')

# %%
plt.plot(iris.sepal_length, iris.sepal_width,"o")

# %%
plt.plot(iris.sepal_length, iris.sepal_width,"*")

# %%
plt.plot(iris.sepal_length, iris.sepal_width,"mv")

# %%
plt.plot(iris.sepal_length, iris.sepal_width,"o", markersize=9)

# %%
plt.scatter(iris.sepal_length, iris.sepal_width)

# %%
plt.scatter(iris.sepal_length, iris.sepal_width,s=50)

# %%
plt.scatter(iris.sepal_length, iris.sepal_width, s=70, color='g')

# %%
plt.scatter(iris.sepal_length, iris.sepal_width, s=70, color='m', marker='*')

# %%
plt.scatter(iris.sepal_length, iris.sepal_width, s=70, color='g', edgecolor='brown',linewidth=0.5)

# %%
plt.scatter(iris.sepal_length, iris.sepal_width, s=70, color='b', edgecolor='yellow',linewidth=1,alpha=0.5)

# %%
color=np.random.randint(0,10,150)
plt.scatter(iris.sepal_length,iris.sepal_width, s=100, c=color, edgecolor='black',alpha=1, linewidth=0.6)

# %%
color=np.random.randint(0,10,150)
plt.scatter(iris.sepal_length,iris.sepal_width, s=100, c=color,cmap='Blues', edgecolor='black',alpha=1, linewidth=0.6)

# %%
plt.scatter(iris.sepal_length,iris.sepal_width, 
            s=100, 
            c=color, 
            cmap="viridis", 
            edgecolor="black", 
            linewidth=1, 
            alpha=1)

# %%
plt.scatter(iris.sepal_length,iris.sepal_width, 
            s=100, 
            c=color, 
            cmap="viridis", 
            edgecolor="black", 
            linewidth=1, 
            alpha=1)
cbar=plt.colorbar()

# %%
plt.scatter(iris.sepal_length,iris.sepal_width, 
            s=100, 
            c=color, 
            cmap="Greens", 
            edgecolor="black", 
            linewidth=1, 
            alpha=1)
cbar=plt.colorbar()
cbar.set_label("Levels")

# %%
plt.scatter(iris.sepal_length,iris.sepal_width, 
            s=100, 
            c=color, 
            cmap="Reds", 
            edgecolor="black", 
            linewidth=1, 
            alpha=1)
plt.xlabel("sepal_width")
plt.ylabel("sepal_length")
plt.title("İris Sepal Length & Sepal Width ")
# Out:
# Text(0.5, 1.0, 'İris Sepal Length & Sepal Width ')

# %%
setosa=iris.loc[iris.species=='setosa']
virginica=iris.loc[iris.species=='virginica']

# %%
setosa.sepal_length.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.kdeplot(setosa.sepal_length, shade=True, color='m')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.histplot(iris.sepal_length,kde=True)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(iris.sepal_length,kde=True,color='m')
sns.histplot(iris.sepal_width,kde=True, color='g')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.kdeplot(data=iris, x="sepal_length", y="sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.kdeplot(data=iris, x="sepal_length", y="sepal_width", shade=True)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
with sns.axes_style('white'):sns.jointplot(data=iris, x="sepal_length",y="sepal_width",kind="hex")

# %%
with sns.axes_style('white'):sns.jointplot(data=iris, x="sepal_length",y="sepal_width",kind="hex")

# %%
sns.pairplot(iris,hue='species')

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_percent']=tips['tip']*100/tips['total_bill']

# %%
grid=sns.FacetGrid(tips, row='smoker',col='time',margin_titles=True)x

# %%
grid.map(plt.hist, "tip_percent", bins=np.linspace(0,40,15))

# %%
Math=np.random.randint(50,100,7)
Stat=np.random.randint(50,100,7)
CS=np.random.randint(50,100,7)

classes=list("ABCDEFG")

# %% [markdown]
# plt.plot(classes, Math, label='Math Avg')
# plt.plot(classes, Stat, label='Stat Avg')
# plt.plot(classes, CS, label='CS Avg')
# plt.legend()
# plt.title('Average of Lessons')
# plt.xlabel('Classes')
# plt.ylabel('Averages')

# %%
plt.plot(classes, Math, label="Math Avg")
plt.plot(classes, Stat, label="Stat Avg")
plt.plot(classes, CS, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
# Out:
# Text(312.8545104506244, 0.5, 'Averages')

# %%
plt.bar(classes, Math, label="Math Avg")
plt.bar(classes, Stat, label="Stat Avg")
plt.bar(classes, CS, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
# Out:
# Text(312.8545104506244, 0.5, 'Averages')

# %%
plt.bar(classes, Math, label="Math Avg")
plt.bar(classes, Stat, label="Stat Avg")
plt.bar(classes, CS, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
